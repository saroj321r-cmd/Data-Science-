# %% [markdown]
# <a href="https://colab.research.google.com/github/saroj321r-cmd/Data-Science-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum(a,b):
  return a+b

sum(2,3)
# Out:
# 5

# %%
# lambda function
x = lambda a : 2*a
print(x(2))
# Out:
# 4

# %%
st=""
print(len(st))

st = "miss sArOj"
st1 = st.upper()
print(x)

st2=st.lower()
print(st2)

st3 = st.title()
print(st3)

st4 = st.capitalize()
print(st4)
# Out:
# 0
# SAROJ
# miss saroj
# Miss Saroj
# Miss saroj

# %%
first = ' Saroj '
second = ' vishwakarma'

#strip - removes spaces from begining and starting
print(first +' '+ second)
# Out:
#  Saroj   vishwakarma

# %%
a= " today "
b= "  weather  "
c= "is GooD  "
first = a.strip().capitalize()
sec = b.strip().lower()
third = c.strip().lower()
fourth = c.replace("is GooD", " is bad")

print(first + ' ' + sec + ' ' + third)
print(first + " "+sec+" "+ fourth)
# Out:
# Today weather is good
# Today weather  is bad

# %%
x = "hello world"
print(x.find("world"))
print(x.startswith("hello"))
print(x.endswith("world"))
# Out:
# 6
# True
# True

# %%
s = {2,2,23,1,4}
print(s)
# Out:
# {1, 2, 4, 23}

# %%
d ={
    "name": "Saroj",
    "age":19,
    "hobbies":["dance","drawing"]
    }

print(d)
print(d['name'])
d['city']="Bilaspur"
print(d)
del d["age"]
print(d)
# Out:
# {'name': 'Saroj', 'age': 19, 'hobbies': ['dance', 'drawing']}
# Saroj
# {'name': 'Saroj', 'age': 19, 'hobbies': ['dance', 'drawing'], 'city': 'Bilaspur'}
# {'name': 'Saroj', 'hobbies': ['dance', 'drawing'], 'city': 'Bilaspur'}
