# %% [markdown]
# <a href="https://colab.research.google.com/github/saroj321r-cmd/Data-Science-/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas = Data ko analyze karne ki library

# %%
import pandas as pd

f = pd.read_csv("student_data.csv",sep=",")
print(f.head())  # first 5 value
print(f.tail())  # last 5 value
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed
#       study_hours  attendance  sleep_hours  internet_usage  \
# 9995            2          58            9               7
# 9996            7          98            6               9
# ...

# %%
import pandas as pd

dct={
    'name':['Arya','Motu','Moti'],
    'age':[12,15,18],
    'roll':[1,2,3]
}
df = pd.DataFrame(dct)
display(df)
# Out:
#    name  age  roll
# 0  Arya   12     1
# 1  Motu   15     2
# 2  Moti   18     3

# %%
df = pd.read_csv('student_data.csv')
#print(df.head(3)) # first 3 values
#print(df.tail(3)) # last 3 values
#print(df.shape) # rows and columns
#print(df.info) # dataframe metadata(file info - columns,datatypes,filetype)
#df.describe() - #statstical summary(mean.med,quartiles,std,min,max)
#df.columns - name of columns
#df.index
#df[['study_hours','internet_usage']] - to acess columns
#df.iloc[0] - # to acess rows

#df.iloc[0:5]
#df.loc[df['study_hours']==11,['study_hours']].iloc[4:8]
#df2 = df.loc[df['study_hours']==11]
#df2[['study_hours','sleep_hours']]

# loc = label , iloc = indexing

#df.loc[df['assignments_completed']==8].iloc[1]

#df[df['assignments_completed']>3]

#df['age']=20

# rename columns
#df=df.rename(columns={'assignments_completed':'assign_completed'}) - it wil return new dataframe
#df

#df.rename(columns={'assignments_completed':'assign_completd'},inplace= True)
#df

# to remove rows or columns
#df.drop(labels=None, axis=0, inplace=False)
#df.drop(1,axis =0)
#df.drop('study_hours',axis =1)

#remove missiing values- df.dropna()
#df.dropna(axis=0, how='an/all', inplace=False)
import numpy as np

d1={
    'roll':[1,2,3],
    'scores':[np.nan,56,78]
}
df1= pd.DataFrame(d1)
print(df1)
#df2 = df1.dropna()
#df2 = df1.dropna(axis =1)
#df2

#df1.dropna(axis=0,inplace= True)
#df1

# check for non misiing values
#df1.notnull()

# replace misising values
#df1.fillna(0)

#find the unique values(for series only )
#df2= pd.Series([1,2,3,4,4,5])
#df2.unique()




# how to use lambda func inside sort value
# Out:
#    roll  scores
# 0     1     NaN
# 1     2    56.0
# 2     3    78.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2842/407759066.py in <cell line: 0>()
#      62 #df2.unique()
#      63
# ---> 64 df.agg(axis=0)
#      65
#      66
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#   10146         axis = self._get_axis_number(axis)
#   10147
# > 10148         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
#   10149         result = op.agg()
#   10150         result = reconstruct_and_relabel_result(result, func, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in frame_apply(obj, func, axis, raw, result_type, by_row, engine, engine_kwargs, args, kwargs)
#     100         klass = FrameColumnApply
#     101
# ...
